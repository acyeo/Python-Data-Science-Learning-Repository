# %%
# Find the 95th quantile
quantile = so_numeric_df['ConvertedSalary'].quantile(0.95)

# Trim the outliers
trimmed_df = so_numeric_df[so_numeric_df['ConvertedSalary'] < quantile]

# The original histogram
so_numeric_df[['ConvertedSalary']].hist()
plt.show()
plt.clf()

# The trimmed histogram
trimmed_df[['ConvertedSalary']].hist()
plt.show()

# %% [markdown]
# ![Screenshot 2024-10-04 at 9.38.25 AM.png](attachment:b670ed38-02d0-44fc-ada1-18d0c1222480.png)![Screenshot 2024-10-04 at 9.38.41 AM.png](attachment:9f3e45f7-f294-4431-8b36-f8d97aa546e0.png)

# %%
# Find the mean and standard dev
std = so_numeric_df['ConvertedSalary'].std()
mean = so_numeric_df['ConvertedSalary'].mean()

# Calculate the cutoff
cut_off = std * 3
lower, upper = mean - cut_off, mean+cut_off

# Trim the outliers
trimmed_df = so_numeric_df[(so_numeric_df['ConvertedSalary'] < upper)  
                           & (so_numeric_df['ConvertedSalary'] > lower)]

# The trimmed box plot
trimmed_df[['ConvertedSalary']].boxplot()
plt.show()

# %% [markdown]
# ![Screenshot 2024-10-04 at 9.41.17 AM.png](attachment:1ead9aa4-057e-4833-bb06-fa843fa4471e.png)![Screenshot 2024-10-04 at 9.41.27 AM.png](attachment:d60d1b47-139e-49a3-ab33-ab956e4b366d.png)![Screenshot 2024-10-04 at 9.41.38 AM.png](attachment:734b991f-0c29-4bc5-8c57-460948326402.png)

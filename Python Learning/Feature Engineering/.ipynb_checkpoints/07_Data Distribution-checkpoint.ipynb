# %%
# Create a histogram
so_numeric_df.hist()
plt.show()

# %% [markdown]
# ![Screenshot 2024-10-04 at 9.06.57 AM.png](attachment:bc354ace-b2ce-4821-bb42-6e9a797c5309.png)

# %%
# Create a boxplot of two columns
so_numeric_df[['Age', 'Years Experience']].boxplot()
plt.show()

# %% [markdown]
# ![Screenshot 2024-10-04 at 9.07.45 AM.png](attachment:d270f1b8-b92c-46a7-9bae-76913ff746e8.png)

# %%
# Create a boxplot of ConvertedSalary
so_numeric_df[['ConvertedSalary']].boxplot()
plt.show()

# %% [markdown]
# ![Screenshot 2024-10-04 at 9.08.57 AM.png](attachment:b9d94166-6c50-4619-aa06-1bd6448388b1.png)

# %%
# Import packages
import matplotlib.pyplot as plt
import seaborn as sns

# Plot pairwise relationships
sns.pairplot(so_numeric_df)

# Show plot
plt.show()

# %% [markdown]
# ![Screenshot 2024-10-04 at 9.10.38 AM.png](attachment:8efef07a-513b-4d83-a2f8-76e68733ccea.png)

# %%
# Print summary statistics
print(so_numeric_df.describe())

        ConvertedSalary      Age  Years Experience
count        9.990e+02  999.000           999.000
mean         6.162e+04   36.003             9.962
std          1.761e+05   13.255             4.878
min          0.000e+00   18.000             0.000
25%          0.000e+00   25.000             7.000
50%          2.712e+04   35.000            10.000
75%          7.000e+04   45.000            13.000
max          2.000e+06   83.000            27.000

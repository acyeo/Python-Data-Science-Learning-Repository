# %% [markdown]
# # Image Augmentation
# - Tool for preventing overfitting
# - takes image already in training data set and manipulates them to create many additional altered images
# - provides more images to train on helps expose neural network model to a wider variety of image variations (i.e reflections, brightness etc.)
# - Check images/sample-train
# - Check images/sample-confirm is empty

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/alexyeo/Desktop/temp/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img
from tensorflow.keras.applications.inception_v3 import preprocess_input

# %% [markdown]
# **Check  that sample-confirm is empty**

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True
)

jf_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    horizontal_flip=True
)

# %% [markdown]
# - the values are all manipulations to the training images

# %% [markdown]
# ## Check on a sample to see the image generators work in the way we expect

# %%
train_generator = train_datagen.flow_from_directory('images/sample-train/',target_size=(150,150), save_to_dir='images/sample-confirm/')
# Out:
# Found 7 images belonging to 2 classes.

# %% [markdown]
# - generate variations of the image data:

# %%
i=0
for batch in train_datagen.flow_from_directory('images/sample-train/', target_size=(150,150), save_to_dir='images/sample-confirm/'):
    i+=1
    if (i>10):
        break
# Out:
# Found 7 images belonging to 2 classes.

# %%
j=0
for batch in jf_datagen.flow_from_directory('images/sample-train/', target_size=(150,150), save_to_dir='images/sample-confirm/'):
    j+=1
    if ( j > 10):
        break
# Out:
# Found 7 images belonging to 2 classes.
